# %%
import time
import datetime as dt
import pandas as pd
import sqlalchemy as sa
from IPython.display import clear_output, display

# 🔗 Connexion à PostgreSQL
engine = sa.create_engine("postgresql+psycopg2://mastodon:mastodon@localhost:5433/mastodon")

print("✅ Connexion PostgreSQL réussie.")

# %%
import time, pandas as pd, sqlalchemy as sa
from IPython.display import clear_output, display

engine = sa.create_engine("postgresql+psycopg2://mastodon:mastodon@localhost:5433/mastodon")

EVERY    = 3      # seconde(s) entre 2 pulls
LIMIT    = 10     # lignes affichées
MIN_NEW  = 1      # nb mini de nouvelles lignes pour redessiner

last_id = None
try:
    i = 0
    while True:
        with engine.connect().execution_options(isolation_level="AUTOCOMMIT") as conn:
            # Dernier id
            mx = pd.read_sql("SELECT max(id) AS mx FROM mastodon_posts;", conn)["mx"].iloc[0]
            if last_id is None:
                last_id = mx

            # Combien de nouvelles lignes ?
            new = (mx or 0) - (last_id or 0)

            if new >= MIN_NEW:
                df = pd.read_sql(sa.text(f"""
                    SELECT id, username, left(content,140) AS preview, ts
                    FROM mastodon_posts
                    ORDER BY id DESC
                    LIMIT :limit
                """), conn, params={"limit": LIMIT})

                clear_output(wait=True)
                print(f"⏱ Refresh #{i} | +{new} nouvelles lignes | id max {mx}")
                display(df)

                last_id = mx
                i += 1

        time.sleep(EVERY)
except KeyboardInterrupt:
    print("⏹️ Live view stopped.")
    print("⏹️ Live view stopped.")
# Out:
# ⏱ Refresh #72 | +11 nouvelles lignes | id max 49628
#       id                              username  \
# 0  49628                   uavideos@osintua.eu
# 1  49627                             tofugolem
# 2  49626  the_fishkeeping_teachers@threads.net
# 3  49625                  SujaMd@flipboard.com
# 4  49624      unclebuckflapjack@nerdculture.de
# 5  49623            ZooTweetMirrorBot@masto.ai
# 6  49622            Cinemaeafins@flipboard.com
# 7  49621    ghostygoo.bsky.social@bsky.brid.gy
# 8  49620                     progressiveparker
# 9  49619             FlipboardUK@flipboard.com
#
#                                              preview  \
# 0  Video : https://videosua.osintukraine.com/medi...
# 1  She has definitely seen photographs of Donald ...
# 2                                     @crustiandaily
# 3  Dog Crate Benefits: Happy Pup and Wallet!https...
# 4  A CPAP alternative that forces bees into your ...
# 5  @𝗡𝗮𝘁𝗶𝗼𝗻𝗮𝗹𝗭𝗼𝗼Due to the government shutdown, we...
# ...
